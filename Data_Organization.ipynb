# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import Data that Will be Needed

# %%
bus_df = pd.read_csv(r"C:\Users\bmmur\Recommendation Concentration\final_yelp_business.csv")
review_df = pd.read_csv(r"C:\Users\bmmur\Recommendation Concentration\yelp_reviews.csv")

# %%
# We only want to study restaurants, so lets only keep businesses that have 'Restaurants or Food' in their name
bus_df = bus_df[bus_df['categories'].str.contains('Restaurant|Restaurants|Food', case=False)]

# %% [markdown]
# #### Create a Primary Category

# %%
# This primary category was created based on the assumption that which every category is listed first by yelp in the categories string is to be 
# viewed as the primary one

# %%
bus_df['categories'] = bus_df['categories'].astype(str)
bus_df['primary_category'] = bus_df['categories'].apply(lambda x: x.split(',')[0].strip())

# %% [markdown]
# #### Create a Subcategory

# %%
# Some businesses have 'restaurant' listed as their primary category. We need to get a specific definition in order to group the restaurants

# %%
skip_terms = ["Restaurant", "Restaurants", "Food", "Specialty Food", "Sandwiches", "Caterers", "Event Planning & Services", "Shopping", 'Nightlife', 
              'Grocery', 'Steakhouses', 'Convenience Stores', 'Drugstores', 'Food Delivery Services', 'Arts & Entertainment', 'Soup', 
              'Meat Shops', 'Chicken Shop', 'Automotive', 'Health Markets', 'Ethnic Food', 'Farmers Market', 'Gas Stations', 'Seafood Markets',
             'Health & Medical', 'Comfort Food', 'Venues & Event Spaces', 'Local Flavor', 'Pharmacy', 'Beauty & Spas', 'Lounges', 'Discount Store', 
              'Department Stores', 'Cosmetics & Beauty Supply', 'Music Venues', 'Hotels & Travel', 'Fashion', 'Discount Store', 'Flowers & Gifts', 
              'Organic Stores', 'Photography Stores & Services', 'Butcher', 'Active Life', 'International Grocery', 'Imported Food', 'Home & Garden',
             'Hotels', 'Electronics', 'Gluten-Free', 'Florists', 'Vitamins & Supplements', 'Party & Event Planning', 'Mobile Phones', 'Wholesale Stores', 
              'Gift Shops', 'Do-It-Yourself Food', 'Herbs & Spices', 'Cheese Shops', 'International' ]

# %%
# Getting the First Real Category into a column 'first_cat'
def classify_category(categories):
    category_list = [cat.strip() for cat in categories.split(',')]
    for category in category_list[:5]:
        if category not in skip_terms:
            return category
    return "Uncategorized"

# %%
bus_df['first_cat'] = bus_df['categories'].apply(classify_category)

# %%
#res_cats = bus_df['first_cat'].value_counts()
#res_cat1 = res_cats[res_cats >= 400]
#print(res_cat1)

# %%
pd.set_option('display.max_rows', None)

# %%
#res_cats = bus_df['first_cat'].value_counts()
#res_cat1 = res_cats[(res_cats > 0) & (res_cats <= 1)]
#print(res_cat1)

# %%
mapping = {'Pizza': 'Fast Food',
           'Coffee & Tea': 'Breakfast',
           'Fast Food': 'Fast Food',
           'American (Traditional)': 'American',
           'Mexican': 'Latin',
           'Bars': 'Nightlife',
           'American (New)': 'American',
           'Chinese': 'Asian',
           'Italian': 'European',
           'Burgers': 'American',
           'Breakfast & Brunch': 'Breakfast',
           'Ice Cream & Frozen Yogurt': 'Dessert',
           'Bakeries': 'Dessert',
           'Delis': 'Lunch',
           'Beer': 'Nightlife',
           'Desserts': 'Desserts',
           'Chicken Wings': 'Fast Food',
           'Cafes': 'Breakfast',
           'Barbeque': 'American',
           'Salad': 'Health',
           'Japanese': 'Asian',
           'Sushi Bars': 'Asian',
           'Juice Bars & Smoothies': 'Health',
           'Donuts': 'Dessert',
           'Thai': 'Asian',
           'Food Trucks': 'Fast Food',
           'Vietnamese': 'Asian',
           'Asian Fusion': 'Asian',
           'Indian': 'Asian',
           'Mediterranean': 'European',
           'Cajun/Creole': 'American',
           'Sports Bars': 'Nightlife',
           'Breweries': 'Nightlife',
           'Tex-Mex': 'Latin',
           'Southern': 'American',
           'Pubs': 'Nightlife',
           'Greek': 'European',
           'Cocktail Bars': 'Nightlife',
           'Bagels': 'Breakfast',
           'Latin American': 'Latin',
           'Vegetarian': 'Healthy',
           'Hot Dogs': 'Fast Food',
           'Caribbean': 'Latin',
           'Fruits & Veggies': 'Healthy',
           'Buffets': 'Fast Food',
           'Korean': 'Asian',
           'Wine Bars': 'Nightlife',
           'Cheesesteaks': 'American',
           'Vegan': 'Healthy',
           'Soul Food': 'American',
           'French': 'European',
           'Middle Eastern': 'Middle Eastern',
           'Tacos': 'Latin',
           'Candy Stores': 'Dessert',
           'Food Stands': 'Fast Food',
           'Bubble Tea': 'Breakfast',
           'Street Vendors': 'Fast Food',
           'Beer Bar': 'Nightlife',
           'Wineries': 'Nightlife',
           'Gastropubs': 'Nightlife',
           'Cupcakes': 'Dessert',
           'Chocolatiers & Shops': 'Dessert',
           'Cuban': 'Latin',
           'Tapas/Small Plates': 'European',
           'Noodles': 'Asian',
           'Halal': 'Middle Eastern',
           'Coffee Roasteries': 'Breakfast',
           'Spanish': 'European',
           'Canadian (New)': 'Canadian',
           'Shaved Ice': 'Dessert',
           'Dive Bars': 'Nightlife',
           'Pakistani': 'Middle Eastern',
           'Tea Rooms': 'Breakfast',
           'Pretzels': 'American',
           'Acai Bowls': 'Healthy',
           'Fish & Chips': 'European',
           'Poke': 'Asian',
           'Custom Cakes': 'Dessert',
           'Wraps': 'Lunch',
           'Hawaiian': 'American',
           'African': 'African',
           'Filipino': 'Asian',
           'Ramen': 'Asian',
           'Tapas Bars': 'European',
           'Pasta Shops': 'European',
           'Irish': 'European',
           'German': 'European',
           'Creperies': 'Breakfast',
           'Gelato': 'Dessert',
           'Seafood': 'Seafood',
           'Waffles': 'Breakfast',
'Karaoke': 'Uncategorized',                  
'Brewpubs': 'Nightlife',
'Food Court': 'Fast Food',
'Dim Sum': 'Asian',
'Furniture Stores': 'Uncategorized',         
'Local Services': 'Uncategorized',           
'Tobacco Shops': 'Uncategorized',            
'Shopping Centers': 'Uncategorized',         
'Distilleries': 'Nightlife',
'Wine Tasting Room'
'Peruvian': 'Latin',
'Donairs': 'Canadian',
'Tours': 'Uncategorized',
'Wedding Planning': 'Uncategorized',
'Festivals': 'Uncategorized',
'Jazz & Blues': 'Nightlife',
'Ethiopian': 'African',
'Brazilian': 'Latin',
'Internet Cafes': 'Breakfast',
'Dance Clubs': 'Nightlife',
'Beer Gardens': 'Nightlife',
'Golf': 'Uncategorized',
'Modern European': 'European',
'Personal Chefs': 'Uncategorized',
'Cantonese': 'Asian',
'Popcorn Shops': 'Fast Food',
'Hookah Bars': 'Nightlife',
'New Mexican Cuisine': 'American',
'Nurseries & Gardening': 'Uncategorized',
'Education': 'Uncategorized',
'Taiwanese': 'Asian',
'Arcades': 'Uncategorized',
'Irish Pub': 'European',
'Puerto Rican': 'Latin',
'Home Services': 'Uncategorized',
'Home Decor': 'Uncategorized',
'Nutritionists': 'Uncategorized',
'Smokehouse': 'American',
'Szechuan': 'Asian',
'Falafel': 'Middle Eastern',
'Arts & Crafts': 'Uncategorized',
'Pop-Up Restaurants'
'Kosher': 'Middle Eastern',
'Turkish': 'Middle Eastern',
'Kitchen & Bath': 'Uncategorized',
'Olive Oil': 'European',
'Live/Raw Food': 'Seafood',
'Service Stations': 'Uncategorized',
'Hot Pot': 'Asian',
'Patisserie/Cake Shop': 'Dessert',
'Empanadas': 'Latin',
'Casinos': 'Uncategorized',
'Food Tours': 'Uncategorized',
'Tires': 'Uncategorized',
'Art Galleries': 'Uncategorized',
'Colombian': 'Latin',
'Polish': 'European',
'Bed & Breakfast': 'Uncategorized',
'Moroccan': 'African',
'Car Wash': 'Uncategorized',
'Cafeteria': 'Uncategorized',
'Kebab': 'Middle Eastern',
'Macarons': 'European',
'British': 'European',
'CSA': 'Farm',
'Delicatessen': 'Lunch',
'Salvadoran': 'Latin',
'Sporting Goods': 'Uncategorized',
'Pan Asian': 'Asian',
'Professional Services': 'Uncategorized',
'Appliances': 'Uncategorized',
'Whiskey Bars': 'Nightlife',
'Indonesian': 'Asian',
'Outlet Stores': 'Uncategorized',
'Afghan': 'Middle Eastern',
'Basque': 'European',
'Vape Shops': 'Uncategorized',
'Bistros': 'Lunch',
'Mongolian': 'Asian',
'Tiki Bars': 'Nightlife',
'Books': 'Uncategorized',
'Laotian': 'Asian',
'Argentine': 'Latin',
'Portuguese': 'European',
'Country Clubs': 'Uncategorized',
'Bowling': 'Uncategorized',
'Hobby Shops': 'Uncategorized',
'Lebanese': 'Middle Eastern',
'Persian/Iranian': 'Middle Eastern',
'Farms': 'Farm',
'Russian': 'European',
'Adult Entertainment': 'Uncategorized',
'Social Clubs': 'Nightlife',
'Dominican': 'Latin',
'Dinner Theater': 'Uncategorized',
'Fondue': 'European',
'Ethnic Grocery': 'Uncategorized',
'Kombucha': 'Healthy',
'Brewing Supplies': 'Uncategorized',
'Weight Loss Centers': 'Uncategorized',
'Beverage Store': 'Uncategorized',
'Gay Bars': 'Nightlife',
'Brasseries': 'European',
'Teppanyaki': 'Asian',
'Pets': 'Uncategorized',
'Public Services & Government': 'Uncategorized',
'Fitness & Instruction': 'Uncategorized',
'Cambodian': 'Asian',
'Public Markets': 'Uncategorized',
'Malaysian': 'Asian',
'Specialty Schools': 'Uncategorized',
'Real Estate': 'Uncategorized',
'Eyewear & Opticians': 'Uncategorized',
'Piano Bars': 'Nightlife',
'Themed Cafes': 'Breakfast',
'Souvenir Shops': 'Uncategorized',
'Cinema': 'Uncategorized',
'Cideries': 'Nightlife',
'Wine Tours': 'Uncategorized',
'Arabic': 'Middle Eastern',
'Day Spas': 'Uncategorized',
'Women\'s Clothing': 'Uncategorized',
'Himalayan/Nepalese': 'Asian',
'Kids Activities': 'Uncategorized',
'Performing Arts': 'Uncategorized',
'Resorts': 'Uncategorized',
'Venezuelan': 'Latin',
'Yoga': 'Uncategorized',
'Shaved Snow': 'Dessert',
'Auto Repair': 'Uncategorized',
'Beer Tours': 'Uncategorized',
'Honey': 'Farm',
'Burmese': 'Asian',
'Pick Your Own Farms': 'Uncategorized',
'Massage': 'Uncategorized',
'Cooking Classes': 'Uncategorized',
'Pool Halls': 'Nightlife',
'Toy Stores': 'Uncategorized',
'Religious Organizations': 'Uncategorized',
'Haitian': 'Latin',
'Pumpkin Patches': 'Uncategorized',
'Party Supplies': 'Uncategorized',
'Pop-up Shops': 'Uncategorized',
'Head Shops': 'Uncategorized',
'Personal Shopping': 'Uncategorized',
'Urgent Care': 'Uncategorized',
'Ukrainian': 'European',
'Newspapers & Magazines': 'Uncategorized',
'Travel Services': 'Uncategorized',
'Historical Tours': 'Uncategorized',
'Boating': 'Uncategorized',
'Candle Stores': 'Uncategorized',
'Office Equipment': 'Uncategorized',
'Belgian': 'European',
'Jewelry': 'Uncategorized',
'Gyms': 'Uncategorized',
'Bartenders': 'Nightlife',
'Limos': 'Uncategorized',
'Honduran': 'Latin',
'Community Service/Non-Profit': 'Uncategorized',
'Poutineries': 'Canadian',
'Herbal Shops': 'Uncategorized',
'Comedy Clubs': 'Uncategorized',
'Transportation': 'Uncategorized',
'Shanghainese': 'Asian',
'Bangladeshi': 'Asian',
'Japanese Curry': 'Asian',
'Izakaya': 'Asian',
'Couriers & Delivery Services': 'Uncategorized',
'Museums': 'Uncategorized',
'Cooking Schools': 'Uncategorized',
'Trinidadian': 'Latin',
'Boat Charters': 'Uncategorized',
'Scandinavian': 'European',
'Hungarian': 'European',
'Adult': 'Uncategorized',
'Accessories': 'Uncategorized',
'Thrift Stores': 'Uncategorized',
'Bridal': 'Uncategorized',
'Cards & Stationery': 'Uncategorized',
'Landmarks & Historical Buildings': 'Uncategorized',
'Food Banks': 'Uncategorized',
'Skin Care': 'Uncategorized',
'Uzbek': 'Asian',
'Sicilian': 'European',
'Tasting Classes': 'Uncategorized',
'Flea Markets': 'Uncategorized',
'Swimming Pools': 'Uncategorized',
'Parking': 'Uncategorized',
'Floral Designers': 'Uncategorized',
'Antiques': 'Uncategorized',
'Armenian': 'European',
'Egyptian': 'African',
'Cabaret': 'Uncategorized',
'Pet Services': 'Uncategorized',
'Tattoo': 'Uncategorized',
'Nail Salons': 'Uncategorized',
'Photographers': 'Uncategorized',
'Pet Stores': 'Uncategorized',
'Hair Salons': 'Uncategorized',
'Speakeasies': 'Nightlife',
'Party Equipment Rentals': 'Uncategorized',
'Men\'s Clothing': 'Uncategorized',
'Optometrists': 'Uncategorized',
'Botanical Gardens': 'Uncategorized',
'Cannabis Dispensaries': 'Uncategorized',
'Coffeeshops': 'Breakfast',
'Fishing': 'Uncategorized',
'Hair Stylists': 'Uncategorized',
'Hair Removal': 'Uncategorized',
'Sports Wear': 'Uncategorized',
'Hardware Stores': 'Uncategorized',
'Blow Dry/Out Services': 'Uncategorized',
'Religious Items': 'Uncategorized',
'Child Care & Day Care': 'Uncategorized',
'Office Cleaning': 'Uncategorized'
          }

# %%
bus_df['subcategory'] = bus_df['first_cat'].map(mapping)

# %%
# Drop the Uncategorized
bus_df = bus_df[bus_df['subcategory'] != 'Uncategorized']

# %%
sub_cats = bus_df['subcategory'].value_counts()
sub_cat1 = sub_cats[sub_cats >= 0]
print(sub_cat1)
# Out:
# subcategory
# Fast Food         9442
# American          9340
# Breakfast         7016
# Asian             6497
# Nightlife         6085
# Dessert           4117
# Latin             4021
# European          3873
# Health            1593
# Seafood           1458
# Lunch             1385
# Desserts          1000
# Healthy            965
# Middle Eastern     537
# Canadian           144
# African            135
# Farm                42
# Australian           1
# Name: count, dtype: int64

# %% [markdown]
# #### Create City Labels

# %%
def assign_city_label(row):
    if 39.5 <= row['latitude'] <= 40.5 and -75.8 <= row['longitude'] <= -74.5:
        if row['state'] in ['PA', 'NJ', 'DE']:
            return 1 # Philadelphia
        else:
            return 99
    elif 34 <= row['latitude'] <= 35 and -120.8 <= row['longitude'] <= -119.0:
        if row['state'] == 'CA':
            return 2 # Santa Barbara
        else:
            return 99
    elif 53 <= row['latitude'] <= 54 and -114 <= row['longitude'] <= -113:
        if row['state'] == 'AB':
            return 3 # Edmonton
        else:
            return 99
    elif 31.75 <= row['latitude'] <= 32.75 and -111.4 <= row['longitude'] <= -110.4:
        if row['state'] == 'AZ':
            return 4 # Tucson
        else:
            return 99
    elif 27.1 <= row['latitude'] <= 28.6 and -83 <= row['longitude'] <= -82:
        if row['state'] == 'FL':
            return 5 # Tampa
        else:
            return 99
    elif 35.55 <= row['latitude'] <= 36.55 and -87.25 <= row['longitude'] <= -86.25:
        if row['state'] == 'TN':
            return 6 # Nashville
        else:
            return 99
    elif 29.3 <= row['latitude'] <= 30.5 and -91 <= row['longitude'] <= -89.6:
        if row['state'] == 'LA':
            return 7 # New Orleans
        else:
            return 99
    elif 39 <= row['latitude'] <= 40.3 and -86.65 <= row['longitude'] <= -85.65:
        if row['state'] == 'IN':
            return 8 # Indianapolis
        else:
            return 99
    elif 43.1 <= row['latitude'] <= 44.1 and -116.7 <= row['longitude'] <= -115.7:
        if row['state'] == 'ID':
            return 9 # Boise
        else:
            return 99
    elif 39 <= row['latitude'] <= 40 and -120.3 <= row['longitude'] <= -119.3:
        if row['state'] in ['CA', 'NV']:
            return 10 # Reno
        else:
            return 99
    elif 38.25 <= row['latitude'] <= 39.25 and -91.5 <= row['longitude'] <= -89.5:
        if row['state'] in ['MO', 'IL']:
            return 11 # St. Louis Suburbs
        else:
            return 99
    else:
        return 99

bus_df['city_label'] = bus_df.apply(assign_city_label, axis=1)

# %% [markdown]
# #### Merge the Data Frames

# %%
bus_df_selected = bus_df[['business_id', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory']]
merged_df = pd.merge(review_df, bus_df_selected, on='business_id', how='left')

# %% [markdown]
# #### Seperate Businesses by Year, Counting the Number of Reviews in Each Star Category

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])
merged_df['year'] = merged_df['date'].dt.year

# %%
grouped_df = merged_df.groupby(['business_id', 'stars', 'year', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory']).size().reset_index(name='count')

# %%
pivot_table = grouped_df.pivot_table(index=['business_id', 'year', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory'],
                                  columns='stars', values='count', fill_value=0).reset_index()
pivot_table.columns = ['business_id', 'year', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory', '1_star', '2_star', '3_star', '4_star', '5_star']

# %%
# Add a single quote before each business_id (without this the CSV file does not recognize multiple dashes in from of a business id)
pivot_table['business_id'] = pivot_table['business_id'].apply(lambda x: f"'{x}")

# %% [markdown]
# #### Seperate Businesses by Month, Counting the Number of Reviews in Each Star Category

# %%
merged_df['month'] = merged_df['date'].dt.month

# %%
monthgrouped_df = merged_df.groupby(['business_id', 'stars', 'year', 'month', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory']).size().reset_index(name='count')

# %%
monthpivot_table = monthgrouped_df.pivot_table(index=['business_id', 'year', 'month', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory'],
                                  columns='stars', values='count', fill_value=0).reset_index()
monthpivot_table.columns = ['business_id', 'year', 'month', 'name', 'city', 'state', 'categories', 'primary_category', 'is_open', 'city_label', 'subcategory', '1_star', '2_star', '3_star', '4_star', '5_star']

# %%
# Add a single quote before each business_id
monthpivot_table['business_id'] = monthpivot_table['business_id'].apply(lambda x: f"'{x}")

# %%
pivot_table.head()
# Out:
#                business_id  year                          name  \
# 0  '---kPU91CF4Lq2-WlRu9Lw  2020             Frankie's Raw Bar
# 1  '---kPU91CF4Lq2-WlRu9Lw  2021             Frankie's Raw Bar
# 2  '---kPU91CF4Lq2-WlRu9Lw  2022             Frankie's Raw Bar
# 3  '--0iUa4sNDFiZFrAdIWhZQ  2009  Pupuseria Y Restaurant Melba
# 4  '--0iUa4sNDFiZFrAdIWhZQ  2010  Pupuseria Y Restaurant Melba
#
#               city state                                         categories  \
# 0  New Port Richey    FL  Seafood, Restaurants, Latin American, Food, Fo...
# 1  New Port Richey    FL  Seafood, Restaurants, Latin American, Food, Fo...
# 2  New Port Richey    FL  Seafood, Restaurants, Latin American, Food, Fo...
# 3        Clementon    NJ  Food, Restaurants, Specialty Food, Mexican, Et...
# 4        Clementon    NJ  Food, Restaurants, Specialty Food, Mexican, Et...
#
#   primary_category  is_open  city_label subcategory  1_star  2_star  3_star  \
# ...

# %%
monthfile_path = r"C:\Users\bmmur\Recommendation Concentration\restaurantbiz_month.csv"
monthpivot_table.to_csv(monthfile_path, index=False)

# %%
yearfile_path = r"C:\Users\bmmur\Recommendation Concentration\restaurantbiz_year.csv"
pivot_table.to_csv(yearfile_path, index=False)
